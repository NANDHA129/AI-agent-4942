# %% [markdown]
# <a href="https://colab.research.google.com/github/NANDHA129/AI-agent-4942/blob/main/Language_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install gTTs

# %%
from gtts import gTTS
from IPython.display import Audio

# %%
a = gTTS(input("enter any text:"))
# Out:
# enter any text:hi hello good morninig

# %%
a.save("speech.mp3")

# %%
Audio("speech.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !pip install SpeechRecognition pydub

# %%
from pydub import AudioSegment
mp3_file='/content/audio.mp3.mp3'
w3v_file='/content/audio.wav'
audio=AudioSegment.from_mp3(mp3_file)
audio.export(w3v_file,format='wav')
# Out:
# <_io.BufferedRandom name='/content/audio.wav'>

# %%
import speech_recognition as sr
reco=sr.Recognizer()
with sr.AudioFile('/content/audio.wav') as source:
  audio_data=reco.record(source)
  text=reco.recognize_google(audio_data)
  print(text)
# Out:
# hello good morning

# %%
from pydub import AudioSegment
mp3_file='/content/my voice.mp3'
w3v_file='/content/my voice.wav'
audio=AudioSegment.from_mp3(mp3_file)
audio.export(w3v_file,format='wav')
# Out:
# <_io.BufferedRandom name='/content/my voice.wav'>

# %%
import speech_recognition as sr
reco=sr.Recognizer()
with sr.AudioFile('/content/my voice.wav') as source:
  audio_data=reco.record(source)
  text=reco.recognize_google(audio_data)
  print(text)
# Out:
# turn off light

# %%
# !pip install pytesseract pillow

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip='/content/handwriting.jpg'
plt.imshow(Image.open(ip))
plt.axis("off")
# Out:
# (-0.5, 2422.5, 2071.5, -0.5)

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip='/content/thrid.jpg'
plt.imshow(Image.open(ip))
plt.axis("off")
# Out:
# (-0.5, 224.5, 224.5, -0.5)

# %%
img=Image.open(ip)
text=pytesseract.image_to_string(img)
print("Extracted text:",text)
# Out:
# Extracted text: ‘
#
# Verbosity (n)
# the fact or quality of
# using more words
#
# than needed;
#
# wordiness.
#
# fy

# %%
# !sudo apt update
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Get:3 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Get:4 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [77.5 kB]
# Get:5 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,683 kB]
# Get:6 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease [18.1 kB]
# Hit:7 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:8 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease [24.3 kB]
# Get:9 https://r2u.stat.illinois.edu/ubuntu jammy/main amd64 Packages [2,726 kB]
# Get:10 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease [24.6 kB]
# ...

# %%
# !sudo apt-get install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 192 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 1s (4,213 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
from PIL import Image
import pytesseract
import matplotlib.pyplot as plt
ip='/content/handwriting.jpg'
plt.imshow(Image.open(ip))
plt.axis("off")
# Out:
# (-0.5, 2422.5, 2071.5, -0.5)

# %%
img=Image.open(ip)
text=pytesseract.image_to_string(img)
print("Extracted text:",text)
# Out:
# Extracted text:

# %%
# !pip install googletrans==4.0.0-rc1

# %%
from googletrans import Translator
t= Translator()
text=input("enter a text:")
translated=t.translate(text,src='en',dest='hi')
print('translated.text:',translated.text)
# Out:
# enter a text:good morning
# translated.text: शुभ प्रभात

# %%
# !pip install gTTs
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.2/98.2 kB 7.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: click
#     Found existing installation: click 8.2.0
#     Uninstalling click-8.2.0:
#       Successfully uninstalled click-8.2.0
# ...

# %%
 # !pip install SpeechRecognition pydub
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 36.5 MB/s eta 0:00:00
# ...

# %%
from pydub import AudioSegment
mp3_file='/content/Thrid.mp3'
wav_file='/content/Thrid.wav'
audio=AudioSegment.from_mp3(mp3_file)
audio.export(wav_file,format='wav')
# Out:
# <_io.BufferedRandom name='/content/Thrid.wav'>

# %%
import speech_recognition as sr
reco=sr.Recognizer()
with sr.AudioFile('/content/Thrid.wav') as source:
  audio_data=reco.record(source)
  text=reco.recognize_google(audio_data)
  print(text)
# Out:
# 5 + 3 - 2

# %%
import speech_recognition as sr
from gtts import gTTS
from IPython.display import Audio

# %%
reco=sr.Recognizer()
with sr.AudioFile('/content/Thrid.wav') as source:
  audio=reco.record(source)
  text=reco.recognize_google(audio)
  print(text)
# Out:
# 5 + 3 - 2

# %%
print("result:",eval(text))
# Out:
# result: 6

# %%
tts=gTTS(text=t,lang='en')
tts.save("result.mp3")

# %%
Audio("result.mp3")
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
